# %% [markdown]
# <h1>UN ENVIRONMENTAL DATA ANALYSIS DECEMBER 2024</h1>
#
# <h2>Analyst: Ahmed Mohamed </h2>
#
# <h3>Date: December 27th, 2024</h3>
#
# <h4>Introduction</h4>
#
# <p>The following analysis is based on a dataset retrieved from the UN Datamart. The dataset is entitled, Carbon dioxide (CO2) Emissions without Land Use, Land-Use Change and Forestry (LULUCF), in kiloton CO2 equivalent.</p>
#
# <p>The dataset provides individual country data with a single data point for each year. The dataset extends from 1990 to 2021 and it is ordered in alphabetical and chronological order. The dataset contains 1375 rows of data. The first row contains the header data. There are three headers entitled, Country or Area, Year, and Value. The Value represents a single annual CO2 data point for each country.
# </p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

df = pd.read_csv('UNPivotData.csv', index_col='Year')

# %%
df.head()
# Out:
#         Australia      Austria       Belarus      Belgium     Bulgaria  \
# Year
# 1990  278154.1563  62167.15967  108345.05510  120292.7992  76637.98583
# 1991  279528.5101  65765.65596  104071.65590  123362.6263  61456.34289
# 1992  284525.3446  60266.15019   93482.97424  122488.4880  57306.46378
# 1993  288870.5368  60692.12767   80561.81536  121423.8760  58364.02380
# 1994  293696.5531  61066.64302   67879.39950  124796.7494  56367.03859
#
#            Canada      Croatia       Cyprus      Czechia      Denmark  ...  \
# Year                                                                   ...
# 1990  458503.0952  22974.68427  4644.860543  164250.4360  54771.39570  ...
# 1991  450159.6022  16985.24886  5133.205072  148883.2734  65364.94820  ...
# 1992  464012.8317  16369.22204  5505.655864  145705.7993  59562.48264  ...
# 1993  464554.1707  16806.46154  5749.299959  140124.0366  61649.82531  ...
# 1994  479033.0030  16049.80543  5991.492676  132668.0357  65704.48928  ...
#
# ...

# %%
df.head(10)
# Out:
#         Australia      Austria       Belarus      Belgium     Bulgaria  \
# Year
# 1990  278154.1563  62167.15967  108345.05510  120292.7992  76637.98583
# 1991  279528.5101  65765.65596  104071.65590  123362.6263  61456.34289
# 1992  284525.3446  60266.15019   93482.97424  122488.4880  57306.46378
# 1993  288870.5368  60692.12767   80561.81536  121423.8760  58364.02380
# 1994  293696.5531  61066.64302   67879.39950  124796.7494  56367.03859
# 1995  305002.9955  64044.05855   60905.64226  125936.2909  57908.98889
# 1996  311886.1290  67388.55460   61734.78374  129478.7377  58460.09661
# 1997  320282.6295  67285.12556   61588.41488  123990.6214  55809.07347
# 1998  334075.9781  66920.02999   60073.44750  130223.4972  53115.14745
# 1999  343488.6329  65671.31074   57965.50697  124681.1402  46318.47750
#
#            Canada      Croatia       Cyprus      Czechia      Denmark  ...  \
# Year                                                                   ...
# ...

# %%
df['Australia']
# Out:
# Year
# 1990    278154.1563
# 1991    279528.5101
# 1992    284525.3446
# 1993    288870.5368
# 1994    293696.5531
# 1995    305002.9955
# 1996    311886.1290
# 1997    320282.6295
# 1998    334075.9781
# 1999    343488.6329
# 2000    349635.4869
# 2001    357132.3675
# 2002    361540.8102
# 2003    369279.5123
# 2004    382820.8901
# 2005    386153.5331
# 2006    392384.3022
# 2007    399624.8027
# 2008    404233.0666
# 2009    407065.0149
# 2010    405103.3205
# 2011    403828.7727
# 2012    406150.9100
# 2013    397887.4584
# 2014    393952.8756
# 2015    401793.0625
# 2016    411264.2877
# 2017    414358.3115
# 2018    416283.8274
# 2019    416761.9334
# 2020    400333.4666
# 2021            NaN
# Name: Australia, dtype: float64

# %%
df = pd.read_csv('UNPivotData.csv', index_col='Year')

# %%
df['Australia']
# Out:
# Year
# 1990    278154.1563
# 1991    279528.5101
# 1992    284525.3446
# 1993    288870.5368
# 1994    293696.5531
# 1995    305002.9955
# 1996    311886.1290
# 1997    320282.6295
# 1998    334075.9781
# 1999    343488.6329
# 2000    349635.4869
# 2001    357132.3675
# 2002    361540.8102
# 2003    369279.5123
# 2004    382820.8901
# 2005    386153.5331
# 2006    392384.3022
# 2007    399624.8027
# 2008    404233.0666
# 2009    407065.0149
# 2010    405103.3205
# 2011    403828.7727
# 2012    406150.9100
# 2013    397887.4584
# 2014    393952.8756
# 2015    401793.0625
# 2016    411264.2877
# 2017    414358.3115
# 2018    416283.8274
# 2019    416761.9334
# 2020    400333.4666
# 2021            NaN
# Name: Australia, dtype: float64

# %%
df['Australia'].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df.Australia
# Out:
# Year
# 1990    278154.1563
# 1991    279528.5101
# 1992    284525.3446
# 1993    288870.5368
# 1994    293696.5531
# 1995    305002.9955
# 1996    311886.1290
# 1997    320282.6295
# 1998    334075.9781
# 1999    343488.6329
# 2000    349635.4869
# 2001    357132.3675
# 2002    361540.8102
# 2003    369279.5123
# 2004    382820.8901
# 2005    386153.5331
# 2006    392384.3022
# 2007    399624.8027
# 2008    404233.0666
# 2009    407065.0149
# 2010    405103.3205
# 2011    403828.7727
# 2012    406150.9100
# 2013    397887.4584
# 2014    393952.8756
# 2015    401793.0625
# 2016    411264.2877
# 2017    414358.3115
# 2018    416283.8274
# 2019    416761.9334
# 2020    400333.4666
# 2021            NaN
# Name: Australia, dtype: float64

# %%
df.loc[1990]
# Out:
# Australia        2.781542e+05
# Austria          6.216716e+04
# Belarus          1.083451e+05
# Belgium          1.202928e+05
# Bulgaria         7.663799e+04
# Canada           4.585031e+05
# Croatia          2.297468e+04
# Cyprus           4.644861e+03
# Czechia          1.642504e+05
# Denmark          5.477140e+04
# Estonia          3.691961e+04
# EU               3.873588e+06
# Finland          5.691433e+04
# France           3.991662e+05
# Germany          1.054741e+06
# Greece           8.343804e+04
# Hungary          7.337683e+04
# Iceland          2.222787e+03
# Ireland          3.294442e+04
# Italy            4.389043e+05
# Japan            1.157196e+06
# Latvia           1.966272e+04
# Liechtenstein    1.989709e+02
# New Zealand      1.064444e+06
# Norway           1.329236e+06
# Poland           1.072190e+07
# ...

# %%
df.sum(axis=0).sort_values()
# Out:
# Monaco           2.797824e+03
# Liechtenstein    6.260755e+03
# Malta            7.581035e+04
# Iceland          9.877886e+04
# Cyprus           2.244188e+05
# Latvia           2.849800e+05
# Luxembourg       3.272083e+05
# Slovenia         4.924410e+05
# Lithuania        4.982927e+05
# Estonia          5.867976e+05
# Croatia          6.279125e+05
# New Zealand      1.064444e+06
# Ireland          1.287089e+06
# Slovakia         1.312836e+06
# Norway           1.329236e+06
# Switzerland      1.357336e+06
# Bulgaria         1.622466e+06
# Sweden           1.651684e+06
# Denmark          1.656883e+06
# Portugal         1.764616e+06
# Finland          1.791494e+06
# Hungary          1.802729e+06
# Belarus          2.072024e+06
# Austria          2.182560e+06
# Greece           2.892565e+06
# Romania          3.242749e+06
# Belgium          3.689096e+06
# Czechia          3.894500e+06
# Netherlands      5.399268e+06
# Spain            9.058766e+06
# Turkey           9.097807e+06
# ...

# %%
df_totals = df.sum(axis=0).sort_values()

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
df_totals.plot(kind = 'bar')
plt.show()

# %%
ax = df_totals.plot(kind = 'bar', figsize=(16, 6), title='CO$_2$ Emissions $_{(1990-2021)}$')
ax.set_ylabel('CO$_2$ (ktonnes)')
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()

# %%
df_totals = df.sum(axis=0).sort_values()[-5:]

# %%
ax = df_totals.plot(kind = 'bar', figsize=(16, 6), title='Top 5 CO$_2$ Emissions $_{(1990-2021)}$')
ax.set_ylabel('CO$_2$ (ktonnes)')
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()

# %%
df_totals = df.sum(axis=0).sort_values()[:5]

# %%
ax = df_totals.plot(kind = 'bar', figsize=(16, 6), title='Lowest 5 CO$_2$ Emissions $_{(1990-2019)}$')
ax.set_ylabel('CO$_2$ (ktonnes)')
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of         Australia      Austria       Belarus       Belgium     Bulgaria  \
# Year
# 1990  278154.1563  62167.15967  108345.05510  120292.79920  76637.98583
# 1991  279528.5101  65765.65596  104071.65590  123362.62630  61456.34289
# 1992  284525.3446  60266.15019   93482.97424  122488.48800  57306.46378
# 1993  288870.5368  60692.12767   80561.81536  121423.87600  58364.02380
# 1994  293696.5531  61066.64302   67879.39950  124796.74940  56367.03859
# 1995  305002.9955  64044.05855   60905.64226  125936.29090  57908.98889
# 1996  311886.1290  67388.55460   61734.78374  129478.73770  58460.09661
# 1997  320282.6295  67285.12556   61588.41488  123990.62140  55809.07347
# 1998  334075.9781  66920.02999   60073.44750  130223.49720  53115.14745
# 1999  343488.6329  65671.31074   57965.50697  124681.14020  46318.47750
# 2000  349635.4869  66171.71962   54905.98293  126721.54380  45413.45742
# ...

# %%
df_totals.to_csv('new_df.csv')
